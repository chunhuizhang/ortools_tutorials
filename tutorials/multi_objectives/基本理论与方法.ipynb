# %%
from IPython.display import Image

# %% [markdown]
# ## 基本概念

# %% [markdown]
# - references:
#     - https://engineering.purdue.edu/~sudhoff/ee630/Lecture09.pdf

# %% [markdown]
# ### dominace

# %%
Image('../../imgs/dominance_1.png', width=400)

# %%
Image('../../imgs/dominance_2.png', width=400)

# %% [markdown]
# - 1 Vs 2: 1 dominates 2
# - 1 Vs 5: 5 dominates 1
# - 1 Vs 4: Neither solution dominates

# %% [markdown]
# ## eplsion约束法（eplsion constraint method）

# %% [markdown]
# - 将除了一个主要目标外的其他目标转化为约束条件

# %% [markdown]
# ## NSGA, NSGAII, NSGAIII

# %% [markdown]
# - Non-dominated Sorting Genetic Algorithm
#     - https://medium.com/@evertongomede/nsga-iii-multi-objective-evolutionary-optimization-for-pareto-front-approximation-ebafb9f1a6ee
