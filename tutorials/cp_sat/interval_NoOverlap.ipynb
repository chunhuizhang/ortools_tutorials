# %%
#!pip install ortools

# %%
from ortools.sat.python import cp_model

# 创建模型
model = cp_model.CpModel()

# %% [markdown]
# ##  `model.AddNoOverlap`

# %% [markdown]
# - `interval` 区间不重叠
#     - 区间集合，一系列区间集合

# %%
# 定义任务的持续时间
duration_task1 = 2
duration_task2 = 3

# 创建两个任务
task1_start = model.NewIntVar(0, 100, 'start_task1')
task1_end = model.NewIntVar(0, 100, 'end_task1')
task1_interval = model.NewIntervalVar(task1_start, duration_task1, task1_end, 'interval_task1')

task2_start = model.NewIntVar(0, 100, 'start_task2')
task2_end = model.NewIntVar(0, 100, 'end_task2')
task2_interval = model.NewIntervalVar(task2_start, duration_task2, task2_end, 'interval_task2')

# %%
# 添加NoOverlap约束
model.AddNoOverlap([task1_interval, task2_interval])

# 求解模型
solver = cp_model.CpSolver()
status = solver.Solve(model)

# 打印解决方案
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    print("Solution:")
    print("Task1 starts at", solver.Value(task1_start))
    print("Task1 ends at", solver.Value(task1_end))
    print("Task2 starts at", solver.Value(task2_start))
    print("Task2 ends at", solver.Value(task2_end))
else:
    print("No solution found")
# Out:
# Solution:
# Task1 starts at 0
# Task1 ends at 2
# Task2 starts at 2
# Task2 ends at 5

# %%
# 添加NoOverlap约束
model.AddNoOverlap([task1_interval, task2_interval])
# 任务2在任务1前
model.Add(task2_end <= task1_start)
# 求解模型
solver = cp_model.CpSolver()
status = solver.Solve(model)

# 打印解决方案
if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
    print("Solution:")
    print("Task1 starts at", solver.Value(task1_start))
    print("Task1 ends at", solver.Value(task1_end))
    print("Task2 starts at", solver.Value(task2_start))
    print("Task2 ends at", solver.Value(task2_end))
else:
    print("No solution found")
# Out:
# Solution:
# Task1 starts at 3
# Task1 ends at 5
# Task2 starts at 0
# Task2 ends at 3

# %% [markdown]
# ## packing

# %%
from ortools.sat.python import cp_model

# Instance
container = (40, 15)
boxes = [
    (11, 3),
    (13, 3),
    (9,  2),
    (7,  2),
    (9,  3),
    (7,  3),
    (11, 2),
    (13, 2),
    (11, 4),
    (13, 4),
    (3,  5),
    (11, 2),
    (2,  2),
    (11, 3),
    (2,  3),
    (5,  4),
    (6,  4),
    (12, 2),
    (1,  2),
    (3,  5),
    (13, 5),
    (12, 4),
    (1,  4),
    (5,  2),
    #(6,  2),  # add to make tight
    # (6,3), # add to make infeasible
]
model = cp_model.CpModel()

# We have to create the variable for the bottom left corner of the boxes.
# We directly limit their range, such that the boxes are inside the container
x_vars = [model.NewIntVar(0, container[0]-box[0], name = f'x1_{i}') for i, box in enumerate(boxes)]
y_vars = [model.NewIntVar(0, container[1]-box[1], name = f'y1_{i}') for i, box in enumerate(boxes)]
# Interval variables are actually more like constraint containers, that are then passed to the no overlap constraint
# Note that we could also make size and end variables, but we don't need them here
x_interval_vars = [model.NewIntervalVar(start=x_vars[i], size=box[0], end=x_vars[i]+box[0], name = f'x_interval_{i}') for i, box in enumerate(boxes)]
y_interval_vars = [model.NewIntervalVar(start=y_vars[i], size=box[1], end=y_vars[i]+box[1], name = f'y_interval_{i}') for i, box in enumerate(boxes)]
# Enforce that no two rectangles overlap
model.AddNoOverlap2D(x_interval_vars, y_interval_vars)

# Solve!
solver = cp_model.CpSolver()
solver.parameters.log_search_progress = True
solver.log_callback = print
status = solver.Solve(model)
assert status == cp_model.OPTIMAL
for i, box in enumerate(boxes):
    print(f'box {i} is placed at ({solver.Value(x_vars[i])}, {solver.Value(y_vars[i])})')
# Out:
# Starting CP-SAT solver v9.7.2996
#
# Starting CP-SAT solver v9.7.2996
# Parameters: log_search_progress: true
# Setting number of workers to 64
# Parameters: log_search_progress: true
# Setting number of workers to 64
#
#
# Initial satisfaction model '': (model_fingerprint: 0x932179154af0ad79)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# Initial satisfaction model '': (model_fingerprint: 0x932179154af0ad79)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kLinear1: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Starting presolve at 0.00s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=0.000160312s
# [ExtractEncodingFromLinear] #potential_supersets=0 #potential_subsets=0 #at_most_one_encodings=0 #exactly_one_encodings=0 #unique_terms=0 #multiple_terms=0 #literals=0 time=0.000160312s
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 9.2732e-05 dtime: 5.681e-05
# [Symmetry] Symmetry computation done. time: 9.2732e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] 6 orbits with sizes: 2,2,2,2,2,2
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Found orbitope of size 2 x 2
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.577e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=8.29e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=8.58e-07s
# [DetectDuplicateConstraints] #duplicates=0 #without_enforcements=0 time=6.577e-06s
# [DetectDominatedLinearConstraints] #relevant_constraints=0 #work_done=0 #num_inclusions=0 #num_redundant=0 time=8.29e-07s
# [ProcessSetPPC] #relevant_constraints=0 #num_inclusions=0 work=0 time=8.58e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.76e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=5.87e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=5.59e-07s
# [FindBigHorizontalLinearOverlap] #blocks=0 #saved_nz=0 #linears=0 #work_done=0/1e+09 time=3.76e-07s
# [FindBigVerticalLinearOverlap] #blocks=0 #nz_reduction=0 #work_done=48 time=5.87e-07s
# [MergeClauses] #num_collisions=0 #num_merges=0 #num_saved_literals=0 work=0/100000000 time=5.59e-07s
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
# Presolved satisfaction model '': (model_fingerprint: 0x84a952283b593e1e)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
#
# Presolve summary:
#   - 0 affine relations were detected.
#   - rule 'TODO dual: only one blocking constraint?' was applied 288 times.
#   - rule 'TODO symmetry: add symmetry breaking inequalities?' was applied 1 time.
#   - rule 'presolve: 0 unused variables removed.' was applied 1 time.
#   - rule 'presolve: iteration' was applied 1 time.
#
# Presolved satisfaction model '': (model_fingerprint: 0x84a952283b593e1e)
# #Variables: 48
#   - 3 in [0,10]
#   - 6 in [0,11]
#   - 6 in [0,12]
#   - 9 in [0,13]
#   - 4 in [0,27]
#   - 2 in [0,28]
#   - 5 in [0,29]
#   - 2 in [0,31]
#   - 2 in [0,33]
#   - 1 in [0,34]
#   - 2 in [0,35]
#   - 2 in [0,37]
#   - 2 in [0,38]
#   - 2 in [0,39]
# #kInterval: 48
# #kNoOverlap2D: 1 (#rectangles: 24)
#
# Preloading model.
# [Symmetry] Graph for symmetry has 193 nodes and 288 arcs.
# [Symmetry] Symmetry computation done. time: 7.6893e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# [Symmetry] Symmetry computation done. time: 7.6893e-05 dtime: 5.681e-05
# [Symmetry] #generators: 3, average support size: 4
# [Symmetry] Found orbitope of size 2 x 2
# #Model   0.01s var:48/48 constraints:49/49
# #Model   0.01s var:48/48 constraints:49/49
#
# Starting search at 0.01s with 64 workers.
# 8 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, probing_max_lp, quick_restart, quick_restart_no_lp]
# 54 first solution subsolvers: [random(27), random_quick_restart(27)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
#
# Starting search at 0.01s with 64 workers.
# 8 full problem subsolvers: [default_lp, less_encoding, max_lp, no_lp, probing, probing_max_lp, quick_restart, quick_restart_no_lp]
# 54 first solution subsolvers: [random(27), random_quick_restart(27)]
# 2 incomplete subsolvers: [feasibility_pump, rins/rens]
# 2 helper subsolvers: [neighborhood_helper, synchronization_agent]
# #1       0.29s probing fixed_bools:0/108
# #1       0.29s probing fixed_bools:0/108
# #2       0.30s probing fixed_bools:0/108
# #2       0.30s probing fixed_bools:0/108
# #3       0.30s probing fixed_bools:0/108
# #3       0.30s probing fixed_bools:0/108
# #4       0.30s probing fixed_bools:0/108
# #4       0.30s probing fixed_bools:0/108
#
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [290.22ms, 290.22ms] 290.22ms   0.00ns 290.22ms         1 [  1.41ms,   1.41ms]   1.41ms   0.00ns   1.41ms
#           'less_encoding':         1 [289.47ms, 289.47ms] 289.47ms   0.00ns 289.47ms         1 [  1.50ms,   1.50ms]   1.50ms   0.00ns   1.50ms
#                   'no_lp':         1 [285.07ms, 285.07ms] 285.07ms   0.00ns 285.07ms         1 [  1.35ms,   1.35ms]   1.35ms   0.00ns   1.35ms
#                  'max_lp':         1 [284.81ms, 284.81ms] 284.81ms   0.00ns 284.81ms         1 [  1.22ms,   1.22ms]   1.22ms   0.00ns   1.22ms
#           'quick_restart':         1 [284.51ms, 284.51ms] 284.51ms   0.00ns 284.51ms         1 [612.98us, 612.98us] 612.98us   0.00ns 612.98us
#     'quick_restart_no_lp':         1 [284.25ms, 284.25ms] 284.25ms   0.00ns 284.25ms         1 [525.43us, 525.43us] 525.43us   0.00ns 525.43us
#                 'probing':         1 [284.16ms, 284.16ms] 284.16ms   0.00ns 284.16ms         1 [496.53us, 496.53us] 496.53us   0.00ns 496.53us
#          'probing_max_lp':         1 [283.92ms, 283.92ms] 283.92ms   0.00ns 283.92ms         1 [  2.23ms,   2.23ms]   2.23ms   0.00ns   2.23ms
#        'feasibility_pump':         1 [385.61us, 385.61us] 385.61us   0.00ns 385.61us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         4 [ 14.65ms, 132.74ms]  74.03ms  56.62ms 296.11ms         1 [460.40us, 460.40us] 460.40us   0.00ns 460.40us
#
# Task timing                        n [     min,      max]      avg      dev     time         n [     min,      max]      avg      dev    dtime
#   'synchronization_agent':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#     'neighborhood_helper':         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#              'default_lp':         1 [290.22ms, 290.22ms] 290.22ms   0.00ns 290.22ms         1 [  1.41ms,   1.41ms]   1.41ms   0.00ns   1.41ms
#           'less_encoding':         1 [289.47ms, 289.47ms] 289.47ms   0.00ns 289.47ms         1 [  1.50ms,   1.50ms]   1.50ms   0.00ns   1.50ms
#                   'no_lp':         1 [285.07ms, 285.07ms] 285.07ms   0.00ns 285.07ms         1 [  1.35ms,   1.35ms]   1.35ms   0.00ns   1.35ms
#                  'max_lp':         1 [284.81ms, 284.81ms] 284.81ms   0.00ns 284.81ms         1 [  1.22ms,   1.22ms]   1.22ms   0.00ns   1.22ms
#           'quick_restart':         1 [284.51ms, 284.51ms] 284.51ms   0.00ns 284.51ms         1 [612.98us, 612.98us] 612.98us   0.00ns 612.98us
#     'quick_restart_no_lp':         1 [284.25ms, 284.25ms] 284.25ms   0.00ns 284.25ms         1 [525.43us, 525.43us] 525.43us   0.00ns 525.43us
#                 'probing':         1 [284.16ms, 284.16ms] 284.16ms   0.00ns 284.16ms         1 [496.53us, 496.53us] 496.53us   0.00ns 496.53us
#          'probing_max_lp':         1 [283.92ms, 283.92ms] 283.92ms   0.00ns 283.92ms         1 [  2.23ms,   2.23ms]   2.23ms   0.00ns   2.23ms
#        'feasibility_pump':         1 [385.61us, 385.61us] 385.61us   0.00ns 385.61us         0 [  0.00ns,   0.00ns]   0.00ns   0.00ns   0.00ns
#               'rins/rens':         4 [ 14.65ms, 132.74ms]  74.03ms  56.62ms 296.11ms         1 [460.40us, 460.40us] 460.40us   0.00ns 460.40us
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':    319        319     1'997         6       7'769          5'491
#         'less_encoding':    347        346     2'188         6       8'546          5'743
#                 'no_lp':    304        305     1'802         6       7'360          5'257
#                'max_lp':    197        234       921         2       4'408          1'917
#         'quick_restart':    303        209     2'310        20       3'217          2'590
#   'quick_restart_no_lp':    329        200     2'224        20       2'931          2'461
#               'probing':    108        280       689        26       2'767          4'806
#        'probing_max_lp':    134        190       272         6       1'287          2'044
#
# Search stats              Bools  Conflicts  Branches  Restarts  BoolPropag  IntegerPropag
#            'default_lp':    319        319     1'997         6       7'769          5'491
#         'less_encoding':    347        346     2'188         6       8'546          5'743
#                 'no_lp':    304        305     1'802         6       7'360          5'257
#                'max_lp':    197        234       921         2       4'408          1'917
#         'quick_restart':    303        209     2'310        20       3'217          2'590
#   'quick_restart_no_lp':    329        200     2'224        20       2'931          2'461
#               'probing':    108        280       689        26       2'767          4'806
#        'probing_max_lp':    134        190       272         6       1'287          2'044
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           4/4     50%        0.60       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      4        0        0        4
#         'lp solutions':     11        4        0        8
#                 'pump':      0        0
#
# LNS stats       Improv/Calls  Closed  Difficulty  TimeLimit
#   'rins/rens':           4/4     50%        0.60       0.10
#
# Solution repositories    Added  Queried  Ignored  Synchro
#   'feasible solutions':      4        0        0        4
#         'lp solutions':     11        4        0        8
#                 'pump':      0        0
#
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 370
# conflicts: 254
# branches: 1686
# propagations: 4381
# integer_propagations: 2352
# restarts: 4
# lp_iterations: 0
# walltime: 0.30494
# usertime: 0.304941
# deterministic_time: 0.0347153
# gap_integral: 0
# solution_fingerprint: 0x397a0422cc046a6
#
# box 0 is placed at (0, 2)
# box 1 is placed at (7, 10)
# box 2 is placed at (0, 5)
# box 3 is placed at (0, 10)
# box 4 is placed at (0, 7)
# box 5 is placed at (0, 12)
# box 6 is placed at (2, 0)
# box 7 is placed at (7, 13)
# box 8 is placed at (9, 6)
# box 9 is placed at (11, 2)
# box 10 is placed at (32, 10)
# box 11 is placed at (29, 5)
# box 12 is placed at (0, 0)
# box 13 is placed at (29, 7)
# box 14 is placed at (24, 2)
# box 15 is placed at (35, 10)
# box 16 is placed at (23, 7)
# box 17 is placed at (14, 0)
# box 18 is placed at (13, 0)
# box 19 is placed at (20, 6)
# box 20 is placed at (26, 0)
# box 21 is placed at (20, 11)
# box 22 is placed at (39, 0)
# box 23 is placed at (24, 5)
# CpSolverResponse summary:
# status: OPTIMAL
# objective: NA
# best_bound: NA
# integers: 48
# booleans: 370
# conflicts: 254
# branches: 1686
# propagations: 4381
# integer_propagations: 2352
# restarts: 4
# lp_iterations: 0
# walltime: 0.30494
# usertime: 0.304941
# deterministic_time: 0.0347153
# gap_integral: 0
# solution_fingerprint: 0x397a0422cc046a6
